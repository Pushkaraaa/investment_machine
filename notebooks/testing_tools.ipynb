# %% [markdown]
# # Screener Demo

# %%
import os
import requests
from typing import Dict, List, Any

# Base Screener Abstract Class
class BaseScreener:
    def get_available_criteria(self) -> Dict[str, Any]:
        pass
    
    def screen(self, criteria: Dict[str, Any]) -> List[Dict[str, Any]]:
        pass
    
    def get_stock_details(self, ticker: str) -> Dict[str, Any]:
        pass

# EODHD Screener Implementation
class EODHDScreener(BaseScreener):
    """
    Concrete BaseScreener using EODHD's Financial Data APIs.
    Quick-start docs: <https://eodhd.com/financial-apis/quick-start-with-our-financial-data-apis>[1]
    """

    def __init__(self, api_token: str = None):
        self.api_token = api_token or os.getenv("EODHD_API_TOKEN")
        if not self.api_token:
            raise ValueError("Set EODHD_API_TOKEN env var or pass api_token")
        self.base = "https://eodhd.com/api/"

    def _get(self, path: str, params: Dict[str, Any] = None) -> Any:
        url = f"{self.base}{path}"
        p = {"api_token": self.api_token, "fmt": "json"}
        if params:
            p.update(params)
        resp = requests.get(url, params=p, timeout=10)
        resp.raise_for_status()
        return resp.json()

    def get_available_criteria(self) -> Dict[str, Any]:
        """
        Hard-coded schema of supported filters.
        """
        return {
            "exchange":         ["NSE", "BSE", "US"],
            "market_cap_min":   1e8,        # in local currency
            "market_cap_max":   1e12,
            "pe_ratio_min":     0.0,
            "pe_ratio_max":     100.0,
            "div_yield_min":    0.0,
            "div_yield_max":    0.1,
            "price_min":        1.0,
            "price_max":        1e4,
            "limit":            100
        }

    def screen(self, criteria: Dict[str, Any]) -> List[Dict[str, Any]]:
        """
        1. Load all symbols for the given exchange.
        2. Fetch fundamentals for each.
        3. Apply client-side filters on market cap, PE, dividend yield, and latest price.
        """
        exch = criteria.get("exchange", "NSE")
        # 1. list symbols on that exchange
        symbols = self._get(f"exchange-symbol-list/{exch}", {})  # [ { "Code": "TCS.NS", ... }, ... ] [1]

        results = []
        limit = criteria.get("limit", 100)
        for sym in symbols:
            if len(results) >= limit:
                break
            code = sym.get("Code")
            data = self._get(f"fundamentals/{code}")  # fundamentals + EOD history [1]
            gen = data.get("General", {})
            hist = data.get("EOD", [])
            latest = hist[-1] if hist else {}
            
            # extract fields
            mc   = float(gen.get("MarketCapitalization") or 0)
            pe   = float(gen.get("PERatio") or 0)
            dy   = float(gen.get("DividendYield") or 0)
            price= float(latest.get("close") or 0)

            # apply filters
            if not (criteria["market_cap_min"] <= mc <= criteria["market_cap_max"]):
                continue
            if not (criteria["pe_ratio_min"] <= pe <= criteria["pe_ratio_max"]):
                continue
            if not (criteria["div_yield_min"] <= dy <= criteria["div_yield_max"]):
                continue
            if not (criteria["price_min"] <= price <= criteria["price_max"]):
                continue

            results.append({
                "ticker": code,
                "name": gen.get("Name"),
                "marketCap": mc,
                "peRatio": pe,
                "dividendYield": dy,
                "price": price
            })

        return results

    def get_stock_details(self, ticker: str) -> Dict[str, Any]:
        """
        Returns a unified detail structure combining fundamentals + latest EOD price.
        """
        data = self._get(f"fundamentals/{ticker}")  # [1]
        gen = data.get("General", {})
        hist = data.get("EOD", [])
        latest = hist[-1] if hist else {}

        return {
            "ticker":        gen.get("Symbol"),
            "name":          gen.get("Name"),
            "sector":        gen.get("Sector"),
            "industry":      gen.get("Industry"),
            "country":       gen.get("Country"),
            "marketCap":     gen.get("MarketCapitalization"),
            "peRatio":       gen.get("PERatio"),
            "dividendYield": gen.get("DividendYield"),
            "latestPrice":   latest.get("close")
        }

# Replace with your actual API token
screener = EODHDScreener("682793d3735129.70503041")
print("Filters:", screener.get_available_criteria())

# Set up screening criteria
crit = {
    "exchange":       "NSE",
    "market_cap_min": 1e10,
    "market_cap_max": 5e11,
    "pe_ratio_min":   0,
    "pe_ratio_max":   50,
    "div_yield_min":  0,
    "div_yield_max":  0.05,
    "price_min":      10,
    "price_max":      2000,
    "limit":          20
}

# Run the screen
hits = screener.screen(crit)
print(f"Found {len(hits)} stocks:", [h["ticker"] for h in hits])

# Get details for a specific stock
detail = screener.get_stock_details("TCS.NS")
print("TCS Details:", detail)
# Out:
# Filters: {'exchange': ['NSE', 'BSE', 'US'], 'market_cap_min': 100000000.0, 'market_cap_max': 1000000000000.0, 'pe_ratio_min': 0.0, 'pe_ratio_max': 100.0, 'div_yield_min': 0.0, 'div_yield_max': 0.1, 'price_min': 1.0, 'price_max': 10000.0, 'limit': 100}
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[13], line 143
#     129 crit = {
#     130     "exchange":       "NSE",
#     131     "market_cap_min": 1e10,
#    (...)
#     139     "limit":          20
#     140 }
#     142 # Run the screen
# --> 143 hits = screener.screen(crit)
#     144 print(f"Found {len(hits)} stocks:", [h["ticker"] for h in hits])
#     146 # Get details for a specific stock
#
# Cell In[13], line 71, in EODHDScreener.screen(self, criteria)
#      69     break
#      70 code = sym.get("Code")
# ---> 71 data = self._get(f"fundamentals/{code}")  # fundamentals + EOD history [1]
#      72 gen = data.get("General", {})
#      73 hist = data.get("EOD", [])
#
# Cell In[13], line 35, in EODHDScreener._get(self, path, params)
#      33     p.update(params)
#      34 resp = requests.get(url, params=p, timeout=10)
# ---> 35 resp.raise_for_status()
#      36 return resp.json()
#
# File ~/hobby_projects/trader/investment_machine/venv/lib/python3.9/site-packages/requests/models.py:1024, in Response.raise_for_status(self)
#    1019     http_error_msg = (
#    1020         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1021     )
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 403 Client Error: Forbidden for url: https://eodhd.com/api/fundamentals/0P00009J3K?api_token=682793d3735129.70503041&fmt=json

# %%
# !https://eodhd.com/api/exchange-symbol-list/USA?api_token=682793d3735129.70503041&fmt=json
# Out:
# zsh:1: no matches found: https://eodhd.com/api/exchange-symbol-list/USA?api_token=682793d3735129.70503041

# %% [markdown]
# # Alpha Vantage API Demo
#
# This notebook demonstrates how to use the Alpha Vantage client for fetching financial data, fundamentals, and news & sentiment analysis.

# %%
import sys
import os
import pandas as pd
import matplotlib.pyplot as plt

# Add the project root to the path to enable imports
sys.path.append(os.path.abspath('../..'))

# Import the Alpha Vantage client
from investment_machine.src.tools.data_fetchers.alpha_vantage import AlphaVantageClient
# Out:
# /Users/paggrawal/hobby_projects/trader/investment_machine/venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
# !pip3 install -q pandas matplotlib
# Out:
# WARNING: You are using pip version 21.2.4; however, version 25.1.1 is available.
# You should consider upgrading via the '/Users/paggrawal/hobby_projects/trader/investment_machine/venv/bin/python3 -m pip install --upgrade pip' command.

# %% [markdown]
# ## Initialize the Alpha Vantage Client
#
# You can provide your API key directly or set it as an environment variable `ALPHA_VANTAGE_API_KEY`.

# %%
# Option 1: Read from environment variable
# client = AlphaVantageClient()

# Option 2: Provide API key directly
client = AlphaVantageClient(api_key="JTPKOHNIT0NJYEQ2")

# %%
import json
data = client._make_request({
    "function": "TIME_SERIES_DAILY_ADJUSTED",
    "symbol": "IBM",
    "outputsize": "compact"
})

# %%
data
# Out:
# {'Information': 'Thank you for using Alpha Vantage! This is a premium endpoint. You may subscribe to any of the premium plans at https://www.alphavantage.co/premium/ to instantly unlock all premium endpoints'}

# %%
import os
import json
import pandas as pd

# Log to store responses and errors
log = []

def safe_call(name, fn, *args, **kwargs):
    """Helper to call fn and print summary or error."""
    print(f"\n--- {name} ---")
    entry = {"name": name}
    try:
        res = fn(*args, **kwargs)
        entry["status"] = "success"

        # DataFrame?
        if isinstance(res, pd.DataFrame):
            entry["type"] = "DataFrame"
            entry["shape"] = res.shape
            entry["preview"] = res.head().to_dict()
            print("DataFrame shape:", res.shape)
            print(res.head())

        # Dict?
        elif isinstance(res, dict):
            entry["type"] = "dict"
            keys = list(res.keys())[:5]
            summary = {k: res[k] for k in keys}
            entry["summary"] = summary
            print(f"Dict keys ({len(res)} total), sample:", json.dumps(summary, indent=2))

        else:
            entry["type"] = "other"
            entry["result"] = str(res)
            print("Result:", res)

    except Exception as e:
        entry["status"] = "error"
        entry["error"] = repr(e)
        print("Error:", repr(e))

    log.append(entry)

# 2) Define test symbol
symbol = "IBM"

# 3) Test free endpoints
safe_call("get_company_overview", client.get_company_overview, symbol)
safe_call("get_income_statement", client.get_income_statement, symbol)
safe_call("get_balance_sheet", client.get_balance_sheet, symbol)
safe_call("get_cash_flow", client.get_cash_flow, symbol)

# 4) Test premium endpoint (NEWS_SENTIMENT)
safe_call("get_news_sentiment", client.get_news_sentiment, symbol, None, None, None, 5)

# 5) Test key-metrics helper
safe_call("calculate_key_metrics", client.calculate_key_metrics, symbol)

print("\nAll tests complete.")

# Optional: Save log to JSON file
with open("api_test_log.json", "w") as f:
    json.dump(log, f, indent=2)
# Out:
# --- get_company_overview ---
# Dict keys (52 total), sample: {
#   "Symbol": "IBM",
#   "AssetType": "Common Stock",
#   "Name": "International Business Machines",
#   "Description": "International Business Machines Corporation (IBM) is an American multinational technology company headquartered in Armonk, New York, with operations in over 170 countries. The company began in 1911, founded in Endicott, New York, as the Computing-Tabulating-Recording Company (CTR) and was renamed International Business Machines in 1924. IBM is incorporated in New York. IBM produces and sells computer hardware, middleware and software, and provides hosting and consulting services in areas ranging from mainframe computers to nanotechnology. IBM is also a major research organization, holding the record for most annual U.S. patents generated by a business (as of 2020) for 28 consecutive years. Inventions by IBM include the automated teller machine (ATM), the floppy disk, the hard disk drive, the magnetic stripe card, the relational database, the SQL programming language, the UPC barcode, and dynamic random-access memory (DRAM). The IBM mainframe, exemplified by the System/360, was the dominant computing platform during the 1960s and 1970s.",
#   "CIK": "51143"
# }
#
# --- get_income_statement ---
# Dict keys (3 total), sample: {
#   "symbol": "IBM",
#   "annualReports": [
#     {
#       "fiscalDateEnding": "2024-12-31",
#       "reportedCurrency": "USD",
#       "grossProfit": "35551000000",
#       "totalRevenue": "62753000000",
#       "costOfRevenue": "27201000000",
#       "costofGoodsAndServicesSold": "27201000000",
#       "operatingIncome": "10074000000",
#       "sellingGeneralAndAdministrative": "16737000000",
#       "researchAndDevelopment": "7479000000",
#       "operatingExpenses": "25478000000",
#       "investmentIncomeNet": "None",
#       "netInterestIncome": "-965000000",
#       "interestIncome": "747000000",
#       "interestExpense": "1712000000",
#       "nonInterestIncome": "None",
#       "otherNonOperatingIncome": "None",
#       "depreciation": "None",
#       "depreciationAndAmortization": "4667000000",
#       "incomeBeforeTax": "5797000000",
#       "incomeTaxExpense": "-218000000",
#       "interestAndDebtExpense": "None",
#       "netIncomeFromContinuingOperations": "6015000000",
#       "comprehensiveIncomeNetOfTax": "None",
#       "ebit": "7509000000",
#       "ebitda": "12176000000",
#       "netIncome": "6023000000"
#     },
#     {
#       "fiscalDateEnding": "2023-12-31",
#       "reportedCurrency": "USD",
#       "grossProfit": "34300000000",
#       "totalRevenue": "61860000000",
#       "costOfRevenue": "27560000000",
#       "costofGoodsAndServicesSold": "27560000000",
#       "operatingIncome": "7514000000",
#       "sellingGeneralAndAdministrative": "17952000000",
#       "researchAndDevelopment": "6631000000",
#       "operatingExpenses": "26786000000",
#       "investmentIncomeNet": "None",
#       "netInterestIncome": "-924000000",
#       "interestIncome": "591000000",
#       "interestExpense": "1607000000",
#       "nonInterestIncome": "None",
#       "otherNonOperatingIncome": "None",
#       "depreciation": "None",
#       "depreciationAndAmortization": "4395000000",
#       "incomeBeforeTax": "8690000000",
#       "incomeTaxExpense": "1176000000",
#       "interestAndDebtExpense": "None",
#       "netIncomeFromContinuingOperations": "7099000000",
#       "comprehensiveIncomeNetOfTax": "None",
#       "ebit": "7514000000",
#       "ebitda": "7514000000",
#       "netIncome": "7502000000"
#     },
#     {
#       "fiscalDateEnding": "2022-12-31",
#       "reportedCurrency": "USD",
#       "grossProfit": "32687000000",
#       "totalRevenue": "60530000000",
#       "costOfRevenue": "27842000000",
#       "costofGoodsAndServicesSold": "27842000000",
#       "operatingIncome": "8174000000",
#       "sellingGeneralAndAdministrative": "16103000000",
#       "researchAndDevelopment": "6567000000",
#       "operatingExpenses": "24514000000",
#       "investmentIncomeNet": "None",
#       "netInterestIncome": "-1216000000",
#       "interestIncome": "162000000",
#       "interestExpense": "1216000000",
#       "nonInterestIncome": "None",
#       "otherNonOperatingIncome": "None",
#       "depreciation": "None",
#       "depreciationAndAmortization": "4802000000",
#       "incomeBeforeTax": "1156000000",
#       "incomeTaxExpense": "-626000000",
#       "interestAndDebtExpense": "None",
#       "netIncomeFromContinuingOperations": "1782000000",
#       "comprehensiveIncomeNetOfTax": "None",
#       "ebit": "2372000000",
#       "ebitda": "7174000000",
#       "netIncome": "1640000000"
#     },
#     {
#       "fiscalDateEnding": "2021-12-31",
#       "reportedCurrency": "USD",
#       "grossProfit": "31486000000",
#       "totalRevenue": "57351000000",
#       "costOfRevenue": "25865000000",
#       "costofGoodsAndServicesSold": "25865000000",
#       "operatingIncome": "6832000000",
#       "sellingGeneralAndAdministrative": "17699000000",
#       "researchAndDevelopment": "6488000000",
#       "operatingExpenses": "24654000000",
#       "investmentIncomeNet": "None",
#       "netInterestIncome": "-1103000000",
#       "interestIncome": "52000000",
#       "interestExpense": "1155000000",
#       "nonInterestIncome": "None",
#       "otherNonOperatingIncome": "-873000000",
#       "depreciation": "None",
#       "depreciationAndAmortization": "6417000000",
#       "incomeBeforeTax": "4837000000",
#       "incomeTaxExpense": "124000000",
#       "interestAndDebtExpense": "None",
#       "netIncomeFromContinuingOperations": "4712000000",
#       "comprehensiveIncomeNetOfTax": "None",
#       "ebit": "7021000000",
#       "ebitda": "13438000000",
#       "netIncome": "5742000000"
#     },
#     {
#       "fiscalDateEnding": "2020-12-31",
#       "reportedCurrency": "USD",
#       "grossProfit": "35575000000",
#       "totalRevenue": "73621000000",
#       "costOfRevenue": "38046000000",
#       "costofGoodsAndServicesSold": "38046000000",
#       "operatingIncome": "6895000000",
#       "sellingGeneralAndAdministrative": "20308000000",
#       "researchAndDevelopment": "6333000000",
#       "operatingExpenses": "28680000000",
#       "investmentIncomeNet": "None",
#       "netInterestIncome": "-1183000000",
#       "interestIncome": "105000000",
#       "interestExpense": "1288000000",
#       "nonInterestIncome": "None",
#       "otherNonOperatingIncome": "-861000000",
#       "depreciation": "None",
#       "depreciationAndAmortization": "6695000000",
#       "incomeBeforeTax": "4637000000",
#       "incomeTaxExpense": "-864000000",
#       "interestAndDebtExpense": "None",
#       "netIncomeFromContinuingOperations": "5501000000",
#       "comprehensiveIncomeNetOfTax": "None",
#       "ebit": "6014000000",
#       "ebitda": "12709000000",
#       "netIncome": "5590000000"
#     },
#     {
#       "fiscalDateEnding": "2019-12-31",
#       "reportedCurrency": "USD",
#       "grossProfit": "31533000000",
#       "totalRevenue": "57714000000",
#       "costOfRevenue": "26181000000",
#       "costofGoodsAndServicesSold": "26181000000",
#       "operatingIncome": "7538000000",
#       "sellingGeneralAndAdministrative": "18107000000",
#       "researchAndDevelopment": "5910000000",
#       "operatingExpenses": "23995000000",
#       "investmentIncomeNet": "None",
#       "netInterestIncome": "-995000000",
#       "interestIncome": "349000000",
#       "interestExpense": "1344000000",
#       "nonInterestIncome": "None",
#       "otherNonOperatingIncome": "968000000",
#       "depreciation": "None",
#       "depreciationAndAmortization": "6059000000",
#       "incomeBeforeTax": "7206000000",
#       "incomeTaxExpense": "60000000",
#       "interestAndDebtExpense": "None",
#       "netIncomeFromContinuingOperations": "9435000000",
#       "comprehensiveIncomeNetOfTax": "None",
#       "ebit": "8550000000",
#       "ebitda": "14609000000",
#       "netIncome": "9431000000"
#     },
#     {
#       "fiscalDateEnding": "2018-12-31",
#       "reportedCurrency": "USD",
#       "grossProfit": "36936000000",
#       "totalRevenue": "79591000000",
#       "costOfRevenue": "42655000000",
#       "costofGoodsAndServicesSold": "42655000000",
#       "operatingIncome": "13217000000",
#       "sellingGeneralAndAdministrative": "17397000000",
#       "researchAndDevelopment": "5379000000",
#       "operatingExpenses": "23719000000",
#       "investmentIncomeNet": "None",
#       "netInterestIncome": "-459000000",
#       "interestIncome": "264000000",
#       "interestExpense": "723000000",
#       "nonInterestIncome": "None",
#       "otherNonOperatingIncome": "-1152000000",
#       "depreciation": "None",
#       "depreciationAndAmortization": "4480000000",
#       "incomeBeforeTax": "11342000000",
#       "incomeTaxExpense": "2619000000",
#       "interestAndDebtExpense": "None",
#       "netIncomeFromContinuingOperations": "8723000000",
#       "comprehensiveIncomeNetOfTax": "None",
#       "ebit": "12065000000",
#       "ebitda": "16545000000",
#       "netIncome": "8728000000"
#     },
#     {
#       "fiscalDateEnding": "2017-12-31",
#       "reportedCurrency": "USD",
#       "grossProfit": "36943000000",
#       "totalRevenue": "79139000000",
#       "costOfRevenue": "42196000000",
#       "costofGoodsAndServicesSold": "42196000000",
#       "operatingIncome": "13139000000",
#       "sellingGeneralAndAdministrative": "18110000000",
#       "researchAndDevelopment": "5590000000",
#       "operatingExpenses": "23804000000",
#       "investmentIncomeNet": "None",
#       "netInterestIncome": "-471000000",
#       "interestIncome": "144000000",
#       "interestExpense": "615000000",
#       "nonInterestIncome": "None",
#       "otherNonOperatingIncome": "216000000",
#       "depreciation": "None",
#       "depreciationAndAmortization": "4541000000",
#       "incomeBeforeTax": "11400000000",
#       "incomeTaxExpense": "5642000000",
#       "interestAndDebtExpense": "None",
#       "netIncomeFromContinuingOperations": "5758000000",
#       "comprehensiveIncomeNetOfTax": "None",
#       "ebit": "12015000000",
#       "ebitda": "16556000000",
#       "netIncome": "5753000000"
#     },
#     {
#       "fiscalDateEnding": "2016-12-31",
#       "reportedCurrency": "USD",
#       "grossProfit": "38516000000",
#       "totalRevenue": "79920000000",
#       "costOfRevenue": "41403000000",
#       "costofGoodsAndServicesSold": "41403000000",
#       "operatingIncome": "14677000000",
#       "sellingGeneralAndAdministrative": "18952000000",
#       "researchAndDevelopment": "5726000000",
#       "operatingExpenses": "24878000000",
#       "investmentIncomeNet": "None",
#       "netInterestIncome": "-522000000",
#       "interestIncome": "108000000",
#       "interestExpense": "630000000",
#       "nonInterestIncome": "None",
#       "otherNonOperatingIncome": "-145000000",
#       "depreciation": "None",
#       "depreciationAndAmortization": "4381000000",
#       "incomeBeforeTax": "12330000000",
#       "incomeTaxExpense": "449000000",
#       "interestAndDebtExpense": "None",
#       "netIncomeFromContinuingOperations": "11881000000",
#       "comprehensiveIncomeNetOfTax": "None",
#       "ebit": "12960000000",
#       "ebitda": "17341000000",
#       "netIncome": "11872000000"
#     },
#     {
#       "fiscalDateEnding": "2015-12-31",
#       "reportedCurrency": "USD",
#       "grossProfit": "40684000000",
#       "totalRevenue": "81742000000",
#       "costOfRevenue": "41057000000",
#       "costofGoodsAndServicesSold": "41057000000",
#       "operatingIncome": "16508000000",
#       "sellingGeneralAndAdministrative": "18604000000",
#       "researchAndDevelopment": "5247000000",
#       "operatingExpenses": "24764000000",
#       "investmentIncomeNet": "None",
#       "netInterestIncome": "None",
#       "interestIncome": "None",
#       "interestExpense": "468000000",
#       "nonInterestIncome": "None",
#       "otherNonOperatingIncome": "724000000",
#       "depreciation": "None",
#       "depreciationAndAmortization": "3855000000",
#       "incomeBeforeTax": "15945000000",
#       "incomeTaxExpense": "2581000000",
#       "interestAndDebtExpense": "None",
#       "netIncomeFromContinuingOperations": "13364000000",
#       "comprehensiveIncomeNetOfTax": "None",
#       "ebit": "16413000000",
#       "ebitda": "20268000000",
#       "netIncome": "13190000000"
#     },
#     {
#       "fiscalDateEnding": "2014-12-31",
#       "reportedCurrency": "USD",
#       "grossProfit": "46407000000",
#       "totalRevenue": "92793000000",
#       "costOfRevenue": "46386000000",
#       "costofGoodsAndServicesSold": "46386000000",
#       "operatingIncome": "20338000000",
#       "sellingGeneralAndAdministrative": "21165000000",
#       "researchAndDevelopment": "5437000000",
#       "operatingExpenses": "27541000000",
#       "investmentIncomeNet": "None",
#       "netInterestIncome": "None",
#       "interestIncome": "None",
#       "interestExpense": "484000000",
#       "nonInterestIncome": "None",
#       "otherNonOperatingIncome": "1938000000",
#       "depreciation": "None",
#       "depreciationAndAmortization": "4492000000",
#       "incomeBeforeTax": "19986000000",
#       "incomeTaxExpense": "4234000000",
#       "interestAndDebtExpense": "None",
#       "netIncomeFromContinuingOperations": "15751000000",
#       "comprehensiveIncomeNetOfTax": "None",
#       "ebit": "20470000000",
#       "ebitda": "24962000000",
#       "netIncome": "12022000000"
#     },
#     {
#       "fiscalDateEnding": "2013-12-31",
#       "reportedCurrency": "USD",
#       "grossProfit": "48684000000",
#       "totalRevenue": "98368000000",
#       "costOfRevenue": "49683000000",
#       "costofGoodsAndServicesSold": "49683000000",
#       "operatingIncome": "21500000000",
#       "sellingGeneralAndAdministrative": "21630000000",
#       "researchAndDevelopment": "5743000000",
#       "operatingExpenses": "28216000000",
#       "investmentIncomeNet": "None",
#       "netInterestIncome": "None",
#       "interestIncome": "None",
#       "interestExpense": "402000000",
#       "nonInterestIncome": "None",
#       "otherNonOperatingIncome": "327000000",
#       "depreciation": "None",
#       "depreciationAndAmortization": "4678000000",
#       "incomeBeforeTax": "20244000000",
#       "incomeTaxExpense": "3363000000",
#       "interestAndDebtExpense": "None",
#       "netIncomeFromContinuingOperations": "16483000000",
#       "comprehensiveIncomeNetOfTax": "None",
#       "ebit": "20646000000",
#       "ebitda": "25324000000",
#       "netIncome": "16483000000"
#     },
#     {
#       "fiscalDateEnding": "2012-12-31",
#       "reportedCurrency": "USD",
#       "grossProfit": "50361000000",
#       "totalRevenue": "102874000000",
#       "costOfRevenue": "52513000000",
#       "costofGoodsAndServicesSold": "52513000000",
#       "operatingIncome": "22990000000",
#       "sellingGeneralAndAdministrative": "21746000000",
#       "researchAndDevelopment": "5816000000",
#       "operatingExpenses": "28155000000",
#       "investmentIncomeNet": "None",
#       "netInterestIncome": "None",
#       "interestIncome": "None",
#       "interestExpense": "459000000",
#       "nonInterestIncome": "None",
#       "otherNonOperatingIncome": "843000000",
#       "depreciation": "None",
#       "depreciationAndAmortization": "4676000000",
#       "incomeBeforeTax": "22540000000",
#       "incomeTaxExpense": "5541000000",
#       "interestAndDebtExpense": "None",
#       "netIncomeFromContinuingOperations": "16604000000",
#       "comprehensiveIncomeNetOfTax": "None",
#       "ebit": "22999000000",
#       "ebitda": "27675000000",
#       "netIncome": "16604000000"
#     },
#     {
#       "fiscalDateEnding": "2011-12-31",
#       "reportedCurrency": "USD",
#       "grossProfit": "50138000000",
#       "totalRevenue": "106916000000",
#       "costOfRevenue": "56778000000",
#       "costofGoodsAndServicesSold": "56778000000",
#       "operatingIncome": "21922000000",
#       "sellingGeneralAndAdministrative": "21844000000",
#       "researchAndDevelopment": "6258000000",
#       "operatingExpenses": "28656000000",
#       "investmentIncomeNet": "None",
#       "netInterestIncome": "None",
#       "interestIncome": "None",
#       "interestExpense": "411000000",
#       "nonInterestIncome": "None",
#       "otherNonOperatingIncome": "20000000",
#       "depreciation": "None",
#       "depreciationAndAmortization": "4815000000",
#       "incomeBeforeTax": "21003000000",
#       "incomeTaxExpense": "5148000000",
#       "interestAndDebtExpense": "None",
#       "netIncomeFromContinuingOperations": "15855000000",
#       "comprehensiveIncomeNetOfTax": "None",
#       "ebit": "21414000000",
#       "ebitda": "26229000000",
#       "netIncome": "15855000000"
#     },
#     {
#       "fiscalDateEnding": "2010-12-31",
#       "reportedCurrency": "USD",
#       "grossProfit": "46014000000",
#       "totalRevenue": "99871000000",
#       "costOfRevenue": "53857000000",
#       "costofGoodsAndServicesSold": "53857000000",
#       "operatingIncome": "19985000000",
#       "sellingGeneralAndAdministrative": "20208000000",
#       "researchAndDevelopment": "6026000000",
#       "operatingExpenses": "26670000000",
#       "investmentIncomeNet": "None",
#       "netInterestIncome": "None",
#       "interestIncome": "None",
#       "interestExpense": "368000000",
#       "nonInterestIncome": "None",
#       "otherNonOperatingIncome": "787000000",
#       "depreciation": "None",
#       "depreciationAndAmortization": "4831000000",
#       "incomeBeforeTax": "19723000000",
#       "incomeTaxExpense": "4890000000",
#       "interestAndDebtExpense": "None",
#       "netIncomeFromContinuingOperations": "14833000000",
#       "comprehensiveIncomeNetOfTax": "None",
#       "ebit": "20091000000",
#       "ebitda": "24922000000",
#       "netIncome": "14833000000"
#     },
#     {
#       "fiscalDateEnding": "2009-12-31",
#       "reportedCurrency": "USD",
#       "grossProfit": "43785000000",
#       "totalRevenue": "95758000000",
#       "costOfRevenue": "51973000000",
#       "costofGoodsAndServicesSold": "51973000000",
#       "operatingIncome": "17012000000",
#       "sellingGeneralAndAdministrative": "19269000000",
#       "researchAndDevelopment": "5820000000",
#       "operatingExpenses": "26773000000",
#       "investmentIncomeNet": "None",
#       "netInterestIncome": "None",
#       "interestIncome": "None",
#       "interestExpense": "402000000",
#       "nonInterestIncome": "None",
#       "otherNonOperatingIncome": "351000000",
#       "depreciation": "None",
#       "depreciationAndAmortization": "4994000000",
#       "incomeBeforeTax": "18138000000",
#       "incomeTaxExpense": "4713000000",
#       "interestAndDebtExpense": "None",
#       "netIncomeFromContinuingOperations": "13425000000",
#       "comprehensiveIncomeNetOfTax": "None",
#       "ebit": "18540000000",
#       "ebitda": "23534000000",
#       "netIncome": "13425000000"
#     },
#     {
#       "fiscalDateEnding": "2008-12-31",
#       "reportedCurrency": "USD",
#       "grossProfit": "45661000000",
#       "totalRevenue": "103630000000",
#       "costOfRevenue": "57969000000",
#       "costofGoodsAndServicesSold": "57969000000",
#       "operatingIncome": "15939000000",
#       "sellingGeneralAndAdministrative": "21514000000",
#       "researchAndDevelopment": "6337000000",
#       "operatingExpenses": "29722000000",
#       "investmentIncomeNet": "None",
#       "netInterestIncome": "None",
#       "interestIncome": "None",
#       "interestExpense": "673000000",
#       "nonInterestIncome": "None",
#       "otherNonOperatingIncome": "None",
#       "depreciation": "None",
#       "depreciationAndAmortization": "5450000000",
#       "incomeBeforeTax": "16715000000",
#       "incomeTaxExpense": "4381000000",
#       "interestAndDebtExpense": "None",
#       "netIncomeFromContinuingOperations": "None",
#       "comprehensiveIncomeNetOfTax": "None",
#       "ebit": "17388000000",
#       "ebitda": "22838000000",
#       "netIncome": "12334000000"
#     },
#     {
#       "fiscalDateEnding": "2007-12-31",
#       "reportedCurrency": "USD",
#       "grossProfit": "41729000000",
#       "totalRevenue": "98786000000",
#       "costOfRevenue": "57057000000",
#       "costofGoodsAndServicesSold": "57057000000",
#       "operatingIncome": "13516000000",
#       "sellingGeneralAndAdministrative": "22060000000",
#       "researchAndDevelopment": "6153000000",
#       "operatingExpenses": "28213000000",
#       "investmentIncomeNet": "None",
#       "netInterestIncome": "None",
#       "interestIncome": "None",
#       "interestExpense": "611000000",
#       "nonInterestIncome": "None",
#       "otherNonOperatingIncome": "None",
#       "depreciation": "None",
#       "depreciationAndAmortization": "5201000000",
#       "incomeBeforeTax": "14489000000",
#       "incomeTaxExpense": "4071000000",
#       "interestAndDebtExpense": "None",
#       "netIncomeFromContinuingOperations": "None",
#       "comprehensiveIncomeNetOfTax": "None",
#       "ebit": "15100000000",
#       "ebitda": "20301000000",
#       "netIncome": "10418000000"
#     },
#     {
#       "fiscalDateEnding": "2006-12-31",
#       "reportedCurrency": "USD",
#       "grossProfit": "38295000000",
#       "totalRevenue": "91424000000",
#       "costOfRevenue": "53129000000",
#       "costofGoodsAndServicesSold": "53129000000",
#       "operatingIncome": "11929000000",
#       "sellingGeneralAndAdministrative": "20259000000",
#       "researchAndDevelopment": "6107000000",
#       "operatingExpenses": "26366000000",
#       "investmentIncomeNet": "None",
#       "netInterestIncome": "None",
#       "interestIncome": "None",
#       "interestExpense": "278000000",
#       "nonInterestIncome": "None",
#       "otherNonOperatingIncome": "None",
#       "depreciation": "None",
#       "depreciationAndAmortization": "4983000000",
#       "incomeBeforeTax": "13317000000",
#       "incomeTaxExpense": "3901000000",
#       "interestAndDebtExpense": "None",
#       "netIncomeFromContinuingOperations": "None",
#       "comprehensiveIncomeNetOfTax": "None",
#       "ebit": "13595000000",
#       "ebitda": "18578000000",
#       "netIncome": "9492000000"
#     },
#     {
#       "fiscalDateEnding": "2005-12-31",
#       "reportedCurrency": "USD",
#       "grossProfit": "36532000000",
#       "totalRevenue": "91134000000",
#       "costOfRevenue": "54602000000",
#       "costofGoodsAndServicesSold": "54602000000",
#       "operatingIncome": "9376000000",
#       "sellingGeneralAndAdministrative": "21314000000",
#       "researchAndDevelopment": "5842000000",
#       "operatingExpenses": "27156000000",
#       "investmentIncomeNet": "None",
#       "netInterestIncome": "None",
#       "interestIncome": "None",
#       "interestExpense": "220000000",
#       "nonInterestIncome": "None",
#       "otherNonOperatingIncome": "None",
#       "depreciation": "None",
#       "depreciationAndAmortization": "5188000000",
#       "incomeBeforeTax": "12226000000",
#       "incomeTaxExpense": "4232000000",
#       "interestAndDebtExpense": "None",
#       "netIncomeFromContinuingOperations": "None",
#       "comprehensiveIncomeNetOfTax": "None",
#       "ebit": "12446000000",
#       "ebitda": "17634000000",
#       "netIncome": "7934000000"
#     }
#   ],
#   "quarterlyReports": [
#     {
#       "fiscalDateEnding": "2025-03-31",
#       "reportedCurrency": "USD",
#       "grossProfit": "8031000000",
#       "totalRevenue": "14541000000",
#       "costOfRevenue": "6510000000",
#       "costofGoodsAndServicesSold": "6510000000",
#       "operatingIncome": "1765000000",
#       "sellingGeneralAndAdministrative": "4023000000",
#       "researchAndDevelopment": "1950000000",
#       "operatingExpenses": "6266000000",
#       "investmentIncomeNet": "None",
#       "netInterestIncome": "-264000000",
#       "interestIncome": "191000000",
#       "interestExpense": "455000000",
#       "nonInterestIncome": "None",
#       "otherNonOperatingIncome": "None",
#       "depreciation": "None",
#       "depreciationAndAmortization": "1177000000",
#       "incomeBeforeTax": "1158000000",
#       "incomeTaxExpense": "103000000",
#       "interestAndDebtExpense": "None",
#       "netIncomeFromContinuingOperations": "1054000000",
#       "comprehensiveIncomeNetOfTax": "None",
#       "ebit": "1613000000",
#       "ebitda": "2790000000",
#       "netIncome": "1055000000"
#     },
#     {
#       "fiscalDateEnding": "2024-12-31",
#       "reportedCurrency": "USD",
#       "grossProfit": "10439000000",
#       "totalRevenue": "17553000000",
#       "costOfRevenue": "7114000000",
#       "costofGoodsAndServicesSold": "7114000000",
#       "operatingIncome": "3901000000",
#       "sellingGeneralAndAdministrative": "4325000000",
#       "researchAndDevelopment": "1967000000",
#       "operatingExpenses": "6538000000",
#       "investmentIncomeNet": "None",
#       "netInterestIncome": "-274000000",
#       "interestIncome": "150000000",
#       "interestExpense": "424000000",
#       "nonInterestIncome": "None",
#       "otherNonOperatingIncome": "None",
#       "depreciation": "None",
#       "depreciationAndAmortization": "1113000000",
#       "incomeBeforeTax": "3306000000",
#       "incomeTaxExpense": "379000000",
#       "interestAndDebtExpense": "None",
#       "netIncomeFromContinuingOperations": "2927000000",
#       "comprehensiveIncomeNetOfTax": "None",
#       "ebit": "3730000000",
#       "ebitda": "4843000000",
#       "netIncome": "2914000000"
#     },
#     {
#       "fiscalDateEnding": "2024-09-30",
#       "reportedCurrency": "USD",
#       "grossProfit": "8420000000",
#       "totalRevenue": "14967000000",
#       "costOfRevenue": "6548000000",
#       "costofGoodsAndServicesSold": "6548000000",
#       "operatingIncome": "2177000000",
#       "sellingGeneralAndAdministrative": "4032000000",
#       "researchAndDevelopment": "1876000000",
#       "operatingExpenses": "6242000000",
#       "investmentIncomeNet": "None",
#       "netInterestIncome": "-259000000",
#       "interestIncome": "170000000",
#       "interestExpense": "429000000",
#       "nonInterestIncome": "None",
#       "otherNonOperatingIncome": "None",
#       "depreciation": "None",
#       "depreciationAndAmortization": "1268000000",
#       "incomeBeforeTax": "-802000000",
#       "incomeTaxExpense": "-485000000",
#       "interestAndDebtExpense": "None",
#       "netIncomeFromContinuingOperations": "-317000000",
#       "comprehensiveIncomeNetOfTax": "None",
#       "ebit": "-373000000",
#       "ebitda": "895000000",
#       "netIncome": "-330000000"
#     },
#     {
#       "fiscalDateEnding": "2024-06-30",
#       "reportedCurrency": "USD",
#       "grossProfit": "8950000000",
#       "totalRevenue": "15769000000",
#       "costOfRevenue": "6820000000",
#       "costofGoodsAndServicesSold": "6820000000",
#       "operatingIncome": "2434000000",
#       "sellingGeneralAndAdministrative": "4293000000",
#       "researchAndDevelopment": "1840000000",
#       "operatingExpenses": "6515000000",
#       "investmentIncomeNet": "None",
#       "netInterestIncome": "-210000000",
#       "interestIncome": "217000000",
#       "interestExpense": "427000000",
#       "nonInterestIncome": "None",
#       "otherNonOperatingIncome": "None",
#       "depreciation": "None",
#       "depreciationAndAmortization": "1155000000",
#       "incomeBeforeTax": "2219000000",
#       "incomeTaxExpense": "389000000",
#       "interestAndDebtExpense": "None",
#       "netIncomeFromContinuingOperations": "1830000000",
#       "comprehensiveIncomeNetOfTax": "None",
#       "ebit": "2646000000",
#       "ebitda": "3801000000",
#       "netIncome": "1834000000"
#     },
#     {
#       "fiscalDateEnding": "2024-03-31",
#       "reportedCurrency": "USD",
#       "grossProfit": "7742000000",
#       "totalRevenue": "14461000000",
#       "costOfRevenue": "6719000000",
#       "costofGoodsAndServicesSold": "6719000000",
#       "operatingIncome": "1563000000",
#       "sellingGeneralAndAdministrative": "4086000000",
#       "researchAndDevelopment": "1796000000",
#       "operatingExpenses": "6179000000",
#       "investmentIncomeNet": "None",
#       "netInterestIncome": "-222000000",
#       "interestIncome": "210000000",
#       "interestExpense": "432000000",
#       "nonInterestIncome": "None",
#       "otherNonOperatingIncome": "None",
#       "depreciation": "None",
#       "depreciationAndAmortization": "1131000000",
#       "incomeBeforeTax": "1074000000",
#       "incomeTaxExpense": "-502000000",
#       "interestAndDebtExpense": "None",
#       "netIncomeFromContinuingOperations": "1575000000",
#       "comprehensiveIncomeNetOfTax": "None",
#       "ebit": "1506000000",
#       "ebitda": "2637000000",
#       "netIncome": "1605000000"
#     },
#     {
#       "fiscalDateEnding": "2023-12-31",
#       "reportedCurrency": "USD",
#       "grossProfit": "10267000000",
#       "totalRevenue": "17380000000",
#       "costOfRevenue": "7114000000",
#       "costofGoodsAndServicesSold": "7114000000",
#       "operatingIncome": "3995000000",
#       "sellingGeneralAndAdministrative": "4250000000",
#       "researchAndDevelopment": "1748000000",
#       "operatingExpenses": "6271000000",
#       "investmentIncomeNet": "None",
#       "netInterestIncome": "-262000000",
#       "interestIncome": "143000000",
#       "interestExpense": "405000000",
#       "nonInterestIncome": "None",
#       "otherNonOperatingIncome": "None",
#       "depreciation": "None",
#       "depreciationAndAmortization": "1152000000",
#       "incomeBeforeTax": "3759000000",
#       "incomeTaxExpense": "474000000",
#       "interestAndDebtExpense": "None",
#       "netIncomeFromContinuingOperations": "3285000000",
#       "comprehensiveIncomeNetOfTax": "None",
#       "ebit": "4164000000",
#       "ebitda": "5316000000",
#       "netIncome": "3288000000"
#     },
#     {
#       "fiscalDateEnding": "2023-09-30",
#       "reportedCurrency": "USD",
#       "grossProfit": "8023000000",
#       "totalRevenue": "14752000000",
#       "costOfRevenue": "6729000000",
#       "costofGoodsAndServicesSold": "6729000000",
#       "operatingIncome": "2129000000",
#       "sellingGeneralAndAdministrative": "4155000000",
#       "researchAndDevelopment": "1685000000",
#       "operatingExpenses": "5894000000",
#       "investmentIncomeNet": "None",
#       "netInterestIncome": "-412000000",
#       "interestIncome": "156000000",
#       "interestExpense": "412000000",
#       "nonInterestIncome": "None",
#       "otherNonOperatingIncome": "None",
#       "depreciation": "None",
#       "depreciationAndAmortization": "1093000000",
#       "incomeBeforeTax": "1873000000",
#       "incomeTaxExpense": "159000000",
#       "interestAndDebtExpense": "None",
#       "netIncomeFromContinuingOperations": "1714000000",
#       "comprehensiveIncomeNetOfTax": "None",
#       "ebit": "2285000000",
#       "ebitda": "3378000000",
#       "netIncome": "1704000000"
#     },
#     {
#       "fiscalDateEnding": "2023-06-30",
#       "reportedCurrency": "USD",
#       "grossProfit": "8501000000",
#       "totalRevenue": "15475000000",
#       "costOfRevenue": "6974000000",
#       "costofGoodsAndServicesSold": "6974000000",
#       "operatingIncome": "2161000000",
#       "sellingGeneralAndAdministrative": "4276000000",
#       "researchAndDevelopment": "1687000000",
#       "operatingExpenses": "6340000000",
#       "investmentIncomeNet": "None",
#       "netInterestIncome": "-423000000",
#       "interestIncome": "201000000",
#       "interestExpense": "423000000",
#       "nonInterestIncome": "None",
#       "otherNonOperatingIncome": "261000000",
#       "depreciation": "None",
#       "depreciationAndAmortization": "1077000000",
#       "incomeBeforeTax": "2000000000",
#       "incomeTaxExpense": "419000000",
#       "interestAndDebtExpense": "None",
#       "netIncomeFromContinuingOperations": "1581000000",
#       "comprehensiveIncomeNetOfTax": "None",
#       "ebit": "2423000000",
#       "ebitda": "3500000000",
#       "netIncome": "1583000000"
#     },
#     {
#       "fiscalDateEnding": "2023-03-31",
#       "reportedCurrency": "USD",
#       "grossProfit": "7509000000",
#       "totalRevenue": "14252000000",
#       "costOfRevenue": "6743000000",
#       "costofGoodsAndServicesSold": "6743000000",
#       "operatingIncome": "1177000000",
#       "sellingGeneralAndAdministrative": "4294000000",
#       "researchAndDevelopment": "1655000000",
#       "operatingExpenses": "6332000000",
#       "investmentIncomeNet": "None",
#       "netInterestIncome": "-367000000",
#       "interestIncome": "170000000",
#       "interestExpense": "367000000",
#       "nonInterestIncome": "None",
#       "otherNonOperatingIncome": "245000000",
#       "depreciation": "None",
#       "depreciationAndAmortization": "1074000000",
#       "incomeBeforeTax": "1058000000",
#       "incomeTaxExpense": "124000000",
#       "interestAndDebtExpense": "None",
#       "netIncomeFromContinuingOperations": "934000000",
#       "comprehensiveIncomeNetOfTax": "None",
#       "ebit": "1425000000",
#       "ebitda": "2499000000",
#       "netIncome": "927000000"
#     },
#     {
#       "fiscalDateEnding": "2022-12-31",
#       "reportedCurrency": "USD",
#       "grossProfit": "9632000000",
#       "totalRevenue": "16691000000",
#       "costOfRevenue": "7058000000",
#       "costofGoodsAndServicesSold": "7058000000",
#       "operatingIncome": "3495000000",
#       "sellingGeneralAndAdministrative": "4179000000",
#       "researchAndDevelopment": "1604000000",
#       "operatingExpenses": "6138000000",
#       "investmentIncomeNet": "None",
#       "netInterestIncome": "-313000000",
#       "interestIncome": "64000000",
#       "interestExpense": "313000000",
#       "nonInterestIncome": "None",
#       "otherNonOperatingIncome": "None",
#       "depreciation": "None",
#       "depreciationAndAmortization": "1137000000",
#       "incomeBeforeTax": "3312000000",
#       "incomeTaxExpense": "444000000",
#       "interestAndDebtExpense": "None",
#       "netIncomeFromContinuingOperations": "2869000000",
#       "comprehensiveIncomeNetOfTax": "None",
#       "ebit": "3625000000",
#       "ebitda": "4762000000",
#       "netIncome": "2711000000"
#     },
#     {
#       "fiscalDateEnding": "2022-09-30",
#       "reportedCurrency": "USD",
#       "grossProfit": "7430000000",
#       "totalRevenue": "14106000000",
#       "costOfRevenue": "6677000000",
#       "costofGoodsAndServicesSold": "6677000000",
#       "operatingIncome": "1548000000",
#       "sellingGeneralAndAdministrative": "3832000000",
#       "researchAndDevelopment": "1611000000",
#       "operatingExpenses": "5881000000",
#       "investmentIncomeNet": "None",
#       "netInterestIncome": "-295000000",
#       "interestIncome": "53000000",
#       "interestExpense": "295000000",
#       "nonInterestIncome": "None",
#       "otherNonOperatingIncome": "-5755000000",
#       "depreciation": "None",
#       "depreciationAndAmortization": "1163000000",
#       "incomeBeforeTax": "-4501000000",
#       "incomeTaxExpense": "-1287000000",
#       "interestAndDebtExpense": "None",
#       "netIncomeFromContinuingOperations": "-3214000000",
#       "comprehensiveIncomeNetOfTax": "None",
#       "ebit": "-4206000000",
#       "ebitda": "-3043000000",
#       "netIncome": "-3196000000"
#     },
#     {
#       "fiscalDateEnding": "2022-06-30",
#       "reportedCurrency": "USD",
#       "grossProfit": "8290000000",
#       "totalRevenue": "15535000000",
#       "costOfRevenue": "7246000000",
#       "costofGoodsAndServicesSold": "7246000000",
#       "operatingIncome": "1932000000",
#       "sellingGeneralAndAdministrative": "4177000000",
#       "researchAndDevelopment": "1673000000",
#       "operatingExpenses": "6357000000",
#       "investmentIncomeNet": "None",
#       "netInterestIncome": "-297000000",
#       "interestIncome": "28000000",
#       "interestExpense": "297000000",
#       "nonInterestIncome": "None",
#       "otherNonOperatingIncome": "81000000",
#       "depreciation": "None",
#       "depreciationAndAmortization": "1246000000",
#       "incomeBeforeTax": "1722000000",
#       "incomeTaxExpense": "257000000",
#       "interestAndDebtExpense": "None",
#       "netIncomeFromContinuingOperations": "1465000000",
#       "comprehensiveIncomeNetOfTax": "None",
#       "ebit": "2019000000",
#       "ebitda": "3265000000",
#       "netIncome": "1392000000"
#     },
#     {
#       "fiscalDateEnding": "2022-03-31",
#       "reportedCurrency": "USD",
#       "grossProfit": "7335000000",
#       "totalRevenue": "14197000000",
#       "costOfRevenue": "6862000000",
#       "costofGoodsAndServicesSold": "6862000000",
#       "operatingIncome": "1179000000",
#       "sellingGeneralAndAdministrative": "3965000000",
#       "researchAndDevelopment": "1679000000",
#       "operatingExpenses": "6156000000",
#       "investmentIncomeNet": "None",
#       "netInterestIncome": "-311000000",
#       "interestIncome": "17000000",
#       "interestExpense": "311000000",
#       "nonInterestIncome": "None",
#       "otherNonOperatingIncome": "-246000000",
#       "depreciation": "None",
#       "depreciationAndAmortization": "1256000000",
#       "incomeBeforeTax": "623000000",
#       "incomeTaxExpense": "-39000000",
#       "interestAndDebtExpense": "None",
#       "netIncomeFromContinuingOperations": "662000000",
#       "comprehensiveIncomeNetOfTax": "None",
#       "ebit": "934000000",
#       "ebitda": "2190000000",
#       "netIncome": "733000000"
#     },
#     {
#       "fiscalDateEnding": "2021-12-31",
#       "reportedCurrency": "USD",
#       "grossProfit": "6107000000",
#       "totalRevenue": "3259000000",
#       "costOfRevenue": "-2849000000",
#       "costofGoodsAndServicesSold": "-2849000000",
#       "operatingIncome": "1313000000",
#       "sellingGeneralAndAdministrative": "2770000000",
#       "researchAndDevelopment": "1581000000",
#       "operatingExpenses": "4795000000",
#       "investmentIncomeNet": "None",
#       "netInterestIncome": "-303000000",
#       "interestIncome": "13000000",
#       "interestExpense": "303000000",
#       "nonInterestIncome": "None",
#       "otherNonOperatingIncome": "38000000",
#       "depreciation": "None",
#       "depreciationAndAmortization": "1381000000",
#       "incomeBeforeTax": "1061000000",
#       "incomeTaxExpense": "-241000000",
#       "interestAndDebtExpense": "None",
#       "netIncomeFromContinuingOperations": "2462000000",
#       "comprehensiveIncomeNetOfTax": "None",
#       "ebit": "1364000000",
#       "ebitda": "2745000000",
#       "netIncome": "2332000000"
#     },
#     {
#       "fiscalDateEnding": "2021-09-30",
#       "reportedCurrency": "USD",
#       "grossProfit": "7106000000",
#       "totalRevenue": "13251000000",
#       "costOfRevenue": "6145000000",
#       "costofGoodsAndServicesSold": "6145000000",
#       "operatingIncome": "1336000000",
#       "sellingGeneralAndAdministrative": "3697000000",
#       "researchAndDevelopment": "1606000000",
#       "operatingExpenses": "5770000000",
#       "investmentIncomeNet": "None",
#       "netInterestIncome": "-291000000",
#       "interestIncome": "14000000",
#       "interestExpense": "290000000",
#       "nonInterestIncome": "None",
#       "otherNonOperatingIncome": "-234000000",
#       "depreciation": "None",
#       "depreciationAndAmortization": "1684000000",
#       "incomeBeforeTax": "813000000",
#       "incomeTaxExpense": "-224000000",
#       "interestAndDebtExpense": "None",
#       "netIncomeFromContinuingOperations": "1130000000",
#       "comprehensiveIncomeNetOfTax": "None",
#       "ebit": "1103000000",
#       "ebitda": "2787000000",
#       "netIncome": "1130000000"
#     },
#     {
#       "fiscalDateEnding": "2021-06-30",
#       "reportedCurrency": "USD",
#       "grossProfit": "7852000000",
#       "totalRevenue": "14218000000",
#       "costOfRevenue": "6366000000",
#       "costofGoodsAndServicesSold": "6366000000",
#       "operatingIncome": "1492000000",
#       "sellingGeneralAndAdministrative": "4202000000",
#       "researchAndDevelopment": "1641000000",
#       "operatingExpenses": "6360000000",
#       "investmentIncomeNet": "None",
#       "netInterestIncome": "-270000000",
#       "interestIncome": "11000000",
#       "interestExpense": "281000000",
#       "nonInterestIncome": "None",
#       "otherNonOperatingIncome": "-315000000",
#       "depreciation": "None",
#       "depreciationAndAmortization": "1680000000",
#       "incomeBeforeTax": "912000000",
#       "incomeTaxExpense": "101000000",
#       "interestAndDebtExpense": "None",
#       "netIncomeFromContinuingOperations": "1325000000",
#       "comprehensiveIncomeNetOfTax": "None",
#       "ebit": "1193000000",
#       "ebitda": "2873000000",
#       "netIncome": "1325000000"
#     },
#     {
#       "fiscalDateEnding": "2021-03-31",
#       "reportedCurrency": "USD",
#       "grossProfit": "7027000000",
#       "totalRevenue": "13187000000",
#       "costOfRevenue": "6160000000",
#       "costofGoodsAndServicesSold": "6160000000",
#       "operatingIncome": "862000000",
#       "sellingGeneralAndAdministrative": "4099000000",
#       "researchAndDevelopment": "1616000000",
#       "operatingExpenses": "6165000000",
#       "investmentIncomeNet": "None",
#       "netInterestIncome": "-280000000",
#       "interestIncome": "14000000",
#       "interestExpense": "280000000",
#       "nonInterestIncome": "None",
#       "otherNonOperatingIncome": "-362000000",
#       "depreciation": "None",
#       "depreciationAndAmortization": "1672000000",
#       "incomeBeforeTax": "244000000",
#       "incomeTaxExpense": "-160000000",
#       "interestAndDebtExpense": "None",
#       "netIncomeFromContinuingOperations": "956000000",
#       "comprehensiveIncomeNetOfTax": "None",
#       "ebit": "524000000",
#       "ebitda": "2196000000",
#       "netIncome": "955000000"
#     },
#     {
#       "fiscalDateEnding": "2020-12-31",
#       "reportedCurrency": "USD",
#       "grossProfit": "10523000000",
#       "totalRevenue": "20368000000",
#       "costOfRevenue": "9844000000",
#       "costofGoodsAndServicesSold": "9844000000",
#       "operatingIncome": "1960000000",
#       "sellingGeneralAndAdministrative": "6580000000",
#       "researchAndDevelopment": "1611000000",
#       "operatingExpenses": "8564000000",
#       "investmentIncomeNet": "None",
#       "netInterestIncome": "-317000000",
#       "interestIncome": "15000000",
#       "interestExpense": "317000000",
#       "nonInterestIncome": "None",
#       "otherNonOperatingIncome": "-247000000",
#       "depreciation": "None",
#       "depreciationAndAmortization": "1699000000",
#       "incomeBeforeTax": "1289000000",
#       "incomeTaxExpense": "24000000",
#       "interestAndDebtExpense": "None",
#       "netIncomeFromContinuingOperations": "1263000000",
#       "comprehensiveIncomeNetOfTax": "None",
#       "ebit": "1606000000",
#       "ebitda": "3305000000",
#       "netIncome": "1355000000"
#     },
#     {
#       "fiscalDateEnding": "2020-09-30",
#       "reportedCurrency": "USD",
#       "grossProfit": "8430000000",
#       "totalRevenue": "17561000000",
#       "costOfRevenue": "9130000000",
#       "costofGoodsAndServicesSold": "9130000000",
#       "operatingIncome": "2391000000",
#       "sellingGeneralAndAdministrative": "4011000000",
#       "researchAndDevelopment": "1515000000",
#       "operatingExpenses": "6040000000",
#       "investmentIncomeNet": "None",
#       "netInterestIncome": "-308000000",
#       "interestIncome": "15000000",
#       "interestExpense": "323000000",
#       "nonInterestIncome": "None",
#       "otherNonOperatingIncome": "-253000000",
#       "depreciation": "None",
#       "depreciationAndAmortization": "1683000000",
#       "incomeBeforeTax": "1827000000",
#       "incomeTaxExpense": "128000000",
#       "interestAndDebtExpense": "None",
#       "netIncomeFromContinuingOperations": "1699000000",
#       "comprehensiveIncomeNetOfTax": "None",
#       "ebit": "2150000000",
#       "ebitda": "3833000000",
#       "netIncome": "1697000000"
#     },
#     {
#       "fiscalDateEnding": "2020-06-30",
#       "reportedCurrency": "USD",
#       "grossProfit": "8700000000",
#       "totalRevenue": "18123000000",
#       "costOfRevenue": "9423000000",
#       "costofGoodsAndServicesSold": "9423000000",
#       "operatingIncome": "2073000000",
#       "sellingGeneralAndAdministrative": "4531000000",
#       "researchAndDevelopment": "1582000000",
#       "operatingExpenses": "6627000000",
#       "investmentIncomeNet": "None",
#       "netInterestIncome": "-300000000",
#       "interestIncome": "23000000",
#       "interestExpense": "323000000",
#       "nonInterestIncome": "None",
#       "otherNonOperatingIncome": "-179000000",
#       "depreciation": "None",
#       "depreciationAndAmortization": "1679000000",
#       "incomeBeforeTax": "1571000000",
#       "incomeTaxExpense": "209000000",
#       "interestAndDebtExpense": "None",
#       "netIncomeFromContinuingOperations": "1362000000",
#       "comprehensiveIncomeNetOfTax": "None",
#       "ebit": "1894000000",
#       "ebitda": "3573000000",
#       "netIncome": "1361000000"
#     },
#     {
#       "fiscalDateEnding": "2020-03-31",
#       "reportedCurrency": "USD",
#       "grossProfit": "7922000000",
#       "totalRevenue": "17570000000",
#       "costOfRevenue": "9649000000",
#       "costofGoodsAndServicesSold": "9649000000",
#       "operatingIncome": "459000000",
#       "sellingGeneralAndAdministrative": "5186000000",
#       "researchAndDevelopment": "1625000000",
#       "operatingExpenses": "7462000000",
#       "investmentIncomeNet": "None",
#       "netInterestIncome": "-275000000",
#       "interestIncome": "51000000",
#       "interestExpense": "326000000",
#       "nonInterestIncome": "None",
#       "otherNonOperatingIncome": "-182000000",
#       "depreciation": "None",
#       "depreciationAndAmortization": "1634000000",
#       "incomeBeforeTax": "-49000000",
#       "incomeTaxExpense": "-1226000000",
#       "interestAndDebtExpense": "None",
#       "netIncomeFromContinuingOperations": "1177000000",
#       "comprehensiveIncomeNetOfTax": "None",
#       "ebit": "277000000",
#       "ebitda": "1911000000",
#       "netIncome": "1175000000"
#     },
#     {
#       "fiscalDateEnding": "2019-12-31",
#       "reportedCurrency": "USD",
#       "grossProfit": "11100000000",
#       "totalRevenue": "21777000000",
#       "costOfRevenue": "10677000000",
#       "costofGoodsAndServicesSold": "10677000000",
#       "operatingIncome": "4266000000",
#       "sellingGeneralAndAdministrative": "4690000000",
#       "researchAndDevelopment": "1596000000",
#       "operatingExpenses": "6834000000",
#       "investmentIncomeNet": "None",
#       "netInterestIncome": "-306000000",
#       "interestIncome": "48000000",
#       "interestExpense": "354000000",
#       "nonInterestIncome": "None",
#       "otherNonOperatingIncome": "None",
#       "depreciation": "None",
#       "depreciationAndAmortization": "1650000000",
#       "incomeBeforeTax": "3993000000",
#       "incomeTaxExpense": "324000000",
#       "interestAndDebtExpense": "None",
#       "netIncomeFromContinuingOperations": "3669000000",
#       "comprehensiveIncomeNetOfTax": "None",
#       "ebit": "4347000000",
#       "ebitda": "5997000000",
#       "netIncome": "3670000000"
#     },
#     {
#       "fiscalDateEnding": "2019-09-30",
#       "reportedCurrency": "USD",
#       "grossProfit": "8336000000",
#       "totalRevenue": "18027000000",
#       "costOfRevenue": "9692000000",
#       "costofGoodsAndServicesSold": "9692000000",
#       "operatingIncome": "1924000000",
#       "sellingGeneralAndAdministrative": "4354000000",
#       "researchAndDevelopment": "1553000000",
#       "operatingExpenses": "6411000000",
#       "investmentIncomeNet": "None",
#       "netInterestIncome": "-369000000",
#       "interestIncome": "63000000",
#       "interestExpense": "432000000",
#       "nonInterestIncome": "None",
#       "otherNonOperatingIncome": "None",
#       "depreciation": "None",
#       "depreciationAndAmortization": "1669000000",
#       "incomeBeforeTax": "1522000000",
#       "incomeTaxExpense": "-151000000",
#       "interestAndDebtExpense": "None",
#       "netIncomeFromContinuingOperations": "1673000000",
#       "comprehensiveIncomeNetOfTax": "None",
#       "ebit": "1954000000",
#       "ebitda": "3623000000",
#       "netIncome": "1672000000"
#     },
#     {
#       "fiscalDateEnding": "2019-06-30",
#       "reportedCurrency": "USD",
#       "grossProfit": "9010000000",
#       "totalRevenue": "19161000000",
#       "costOfRevenue": "10151000000",
#       "costofGoodsAndServicesSold": "10151000000",
#       "operatingIncome": "2369000000",
#       "sellingGeneralAndAdministrative": "4923000000",
#       "researchAndDevelopment": "1407000000",
#       "operatingExpenses": "6641000000",
#       "investmentIncomeNet": "None",
#       "netInterestIncome": "-181000000",
#       "interestIncome": "167000000",
#       "interestExpense": "348000000",
#       "nonInterestIncome": "None",
#       "otherNonOperatingIncome": "None",
#       "depreciation": "None",
#       "depreciationAndAmortization": "1294000000",
#       "incomeBeforeTax": "2768000000",
#       "incomeTaxExpense": "269000000",
#       "interestAndDebtExpense": "None",
#       "netIncomeFromContinuingOperations": "2499000000",
#       "comprehensiveIncomeNetOfTax": "None",
#       "ebit": "3116000000",
#       "ebitda": "4410000000",
#       "netIncome": "2498000000"
#     },
#     {
#       "fiscalDateEnding": "2019-03-31",
#       "reportedCurrency": "USD",
#       "grossProfit": "8043000000",
#       "totalRevenue": "18181000000",
#       "costOfRevenue": "10139000000",
#       "costofGoodsAndServicesSold": "10139000000",
#       "operatingIncome": "2021000000",
#       "sellingGeneralAndAdministrative": "4141000000",
#       "researchAndDevelopment": "1433000000",
# ...
#       "proceedsFromRepaymentsOfShortTermDebt": "None",
#       "paymentsForRepurchaseOfCommonStock": "None",
#       "paymentsForRepurchaseOfEquity": "None",
#       "paymentsForRepurchaseOfPreferredStock": "None",
#       "dividendPayout": "554000000",
#       "dividendPayoutCommonStock": "554000000",
#       "dividendPayoutPreferredStock": "None",
#       "proceedsFromIssuanceOfCommonStock": "None",
#       "proceedsFromIssuanceOfLongTermDebtAndCapitalSecuritiesNet": "None",
#       "proceedsFromIssuanceOfPreferredStock": "None",
#       "proceedsFromRepurchaseOfEquity": "-471000000",
#       "proceedsFromSaleOfTreasuryStock": "None",
#       "changeInCashAndCashEquivalents": "None",
#       "changeInExchangeRate": "None",
#       "netIncome": "3951000000"
#     },
#     {
#       "fiscalDateEnding": "2007-09-30",
#       "reportedCurrency": "USD",
#       "operatingCashflow": "4484000000",
#       "paymentsForOperatingActivities": "None",
#       "proceedsFromOperatingActivities": "None",
#       "changeInOperatingLiabilities": "None",
#       "changeInOperatingAssets": "None",
#       "depreciationDepletionAndAmortization": "1340000000",
#       "capitalExpenditures": "1297000000",
#       "changeInReceivables": "None",
#       "changeInInventory": "None",
#       "profitLoss": "None",
#       "cashflowFromInvestment": "None",
#       "cashflowFromFinancing": "889000000",
#       "proceedsFromRepaymentsOfShortTermDebt": "None",
#       "paymentsForRepurchaseOfCommonStock": "None",
#       "paymentsForRepurchaseOfEquity": "None",
#       "paymentsForRepurchaseOfPreferredStock": "None",
#       "dividendPayout": "549000000",
#       "dividendPayoutCommonStock": "549000000",
#       "dividendPayoutPreferredStock": "None",
#       "proceedsFromIssuanceOfCommonStock": "None",
#       "proceedsFromIssuanceOfLongTermDebtAndCapitalSecuritiesNet": "None",
#       "proceedsFromIssuanceOfPreferredStock": "None",
#       "proceedsFromRepurchaseOfEquity": "-152000000",
#       "proceedsFromSaleOfTreasuryStock": "None",
#       "changeInCashAndCashEquivalents": "None",
#       "changeInExchangeRate": "None",
#       "netIncome": "2362000000"
#     },
#     {
#       "fiscalDateEnding": "2007-06-30",
#       "reportedCurrency": "USD",
#       "operatingCashflow": "3446000000",
#       "paymentsForOperatingActivities": "None",
#       "proceedsFromOperatingActivities": "None",
#       "changeInOperatingLiabilities": "None",
#       "changeInOperatingAssets": "None",
#       "depreciationDepletionAndAmortization": "1284000000",
#       "capitalExpenditures": "1110000000",
#       "changeInReceivables": "None",
#       "changeInInventory": "None",
#       "profitLoss": "None",
#       "cashflowFromInvestment": "None",
#       "cashflowFromFinancing": "-3291000000",
#       "proceedsFromRepaymentsOfShortTermDebt": "None",
#       "paymentsForRepurchaseOfCommonStock": "None",
#       "paymentsForRepurchaseOfEquity": "None",
#       "paymentsForRepurchaseOfPreferredStock": "None",
#       "dividendPayout": "592000000",
#       "dividendPayoutCommonStock": "592000000",
#       "dividendPayoutPreferredStock": "None",
#       "proceedsFromIssuanceOfCommonStock": "None",
#       "proceedsFromIssuanceOfLongTermDebtAndCapitalSecuritiesNet": "None",
#       "proceedsFromIssuanceOfPreferredStock": "None",
#       "proceedsFromRepurchaseOfEquity": "-14807000000",
#       "proceedsFromSaleOfTreasuryStock": "None",
#       "changeInCashAndCashEquivalents": "None",
#       "changeInExchangeRate": "None",
#       "netIncome": "2261000000"
#     },
#     {
#       "fiscalDateEnding": "2007-03-31",
#       "reportedCurrency": "USD",
#       "operatingCashflow": "3013000000",
#       "paymentsForOperatingActivities": "None",
#       "proceedsFromOperatingActivities": "None",
#       "changeInOperatingLiabilities": "None",
#       "changeInOperatingAssets": "None",
#       "depreciationDepletionAndAmortization": "1240000000",
#       "capitalExpenditures": "1132000000",
#       "changeInReceivables": "None",
#       "changeInInventory": "None",
#       "profitLoss": "None",
#       "cashflowFromInvestment": "None",
#       "cashflowFromFinancing": "-1717000000",
#       "proceedsFromRepaymentsOfShortTermDebt": "None",
#       "paymentsForRepurchaseOfCommonStock": "None",
#       "paymentsForRepurchaseOfEquity": "None",
#       "paymentsForRepurchaseOfPreferredStock": "None",
#       "dividendPayout": "452000000",
#       "dividendPayoutCommonStock": "452000000",
#       "dividendPayoutPreferredStock": "None",
#       "proceedsFromIssuanceOfCommonStock": "None",
#       "proceedsFromIssuanceOfLongTermDebtAndCapitalSecuritiesNet": "None",
#       "proceedsFromIssuanceOfPreferredStock": "None",
#       "proceedsFromRepurchaseOfEquity": "-3398000000",
#       "proceedsFromSaleOfTreasuryStock": "None",
#       "changeInCashAndCashEquivalents": "None",
#       "changeInExchangeRate": "None",
#       "netIncome": "1844000000"
#     },
#     {
#       "fiscalDateEnding": "2006-12-31",
#       "reportedCurrency": "USD",
#       "operatingCashflow": "5343000000",
#       "paymentsForOperatingActivities": "None",
#       "proceedsFromOperatingActivities": "None",
#       "changeInOperatingLiabilities": "None",
#       "changeInOperatingAssets": "None",
#       "depreciationDepletionAndAmortization": "1300000000",
#       "capitalExpenditures": "1805000000",
#       "changeInReceivables": "None",
#       "changeInInventory": "112000000",
#       "profitLoss": "None",
#       "cashflowFromInvestment": "None",
#       "cashflowFromFinancing": "-303000000",
#       "proceedsFromRepaymentsOfShortTermDebt": "None",
#       "paymentsForRepurchaseOfCommonStock": "None",
#       "paymentsForRepurchaseOfEquity": "None",
#       "paymentsForRepurchaseOfPreferredStock": "None",
#       "dividendPayout": "452000000",
#       "dividendPayoutCommonStock": "452000000",
#       "dividendPayoutPreferredStock": "None",
#       "proceedsFromIssuanceOfCommonStock": "None",
#       "proceedsFromIssuanceOfLongTermDebtAndCapitalSecuritiesNet": "None",
#       "proceedsFromIssuanceOfPreferredStock": "None",
#       "proceedsFromRepurchaseOfEquity": "None",
#       "proceedsFromSaleOfTreasuryStock": "None",
#       "changeInCashAndCashEquivalents": "None",
#       "changeInExchangeRate": "None",
#       "netIncome": "3540000000"
#     },
#     {
#       "fiscalDateEnding": "2006-09-30",
#       "reportedCurrency": "USD",
#       "operatingCashflow": "4006000000",
#       "paymentsForOperatingActivities": "None",
#       "proceedsFromOperatingActivities": "None",
#       "changeInOperatingLiabilities": "None",
#       "changeInOperatingAssets": "None",
#       "depreciationDepletionAndAmortization": "1228000000",
#       "capitalExpenditures": "1259000000",
#       "changeInReceivables": "None",
#       "changeInInventory": "None",
#       "profitLoss": "None",
#       "cashflowFromInvestment": "None",
#       "cashflowFromFinancing": "-1655000000",
#       "proceedsFromRepaymentsOfShortTermDebt": "None",
#       "paymentsForRepurchaseOfCommonStock": "None",
#       "paymentsForRepurchaseOfEquity": "None",
#       "paymentsForRepurchaseOfPreferredStock": "None",
#       "dividendPayout": "455000000",
#       "dividendPayoutCommonStock": "455000000",
#       "dividendPayoutPreferredStock": "None",
#       "proceedsFromIssuanceOfCommonStock": "None",
#       "proceedsFromIssuanceOfLongTermDebtAndCapitalSecuritiesNet": "None",
#       "proceedsFromIssuanceOfPreferredStock": "None",
#       "proceedsFromRepurchaseOfEquity": "-1627000000",
#       "proceedsFromSaleOfTreasuryStock": "None",
#       "changeInCashAndCashEquivalents": "None",
#       "changeInExchangeRate": "None",
#       "netIncome": "2222000000"
#     },
#     {
#       "fiscalDateEnding": "2006-06-30",
#       "reportedCurrency": "USD",
#       "operatingCashflow": "2564000000",
#       "paymentsForOperatingActivities": "None",
#       "proceedsFromOperatingActivities": "None",
#       "changeInOperatingLiabilities": "None",
#       "changeInOperatingAssets": "None",
#       "depreciationDepletionAndAmortization": "1247000000",
#       "capitalExpenditures": "1126000000",
#       "changeInReceivables": "None",
#       "changeInInventory": "None",
#       "profitLoss": "None",
#       "cashflowFromInvestment": "None",
#       "cashflowFromFinancing": "-3693000000",
#       "proceedsFromRepaymentsOfShortTermDebt": "None",
#       "paymentsForRepurchaseOfCommonStock": "None",
#       "paymentsForRepurchaseOfEquity": "None",
#       "paymentsForRepurchaseOfPreferredStock": "None",
#       "dividendPayout": "463000000",
#       "dividendPayoutCommonStock": "463000000",
#       "dividendPayoutPreferredStock": "None",
#       "proceedsFromIssuanceOfCommonStock": "None",
#       "proceedsFromIssuanceOfLongTermDebtAndCapitalSecuritiesNet": "None",
#       "proceedsFromIssuanceOfPreferredStock": "None",
#       "proceedsFromRepurchaseOfEquity": "None",
#       "proceedsFromSaleOfTreasuryStock": "None",
#       "changeInCashAndCashEquivalents": "None",
#       "changeInExchangeRate": "None",
#       "netIncome": "2022000000"
#     },
#     {
#       "fiscalDateEnding": "2006-03-31",
#       "reportedCurrency": "USD",
#       "operatingCashflow": "3106000000",
#       "paymentsForOperatingActivities": "None",
#       "proceedsFromOperatingActivities": "None",
#       "changeInOperatingLiabilities": "None",
#       "changeInOperatingAssets": "None",
#       "depreciationDepletionAndAmortization": "1208000000",
#       "capitalExpenditures": "976000000",
#       "changeInReceivables": "None",
#       "changeInInventory": "None",
#       "profitLoss": "None",
#       "cashflowFromInvestment": "None",
#       "cashflowFromFinancing": "-2553000000",
#       "proceedsFromRepaymentsOfShortTermDebt": "None",
#       "paymentsForRepurchaseOfCommonStock": "None",
#       "paymentsForRepurchaseOfEquity": "None",
#       "paymentsForRepurchaseOfPreferredStock": "None",
#       "dividendPayout": "313000000",
#       "dividendPayoutCommonStock": "313000000",
#       "dividendPayoutPreferredStock": "None",
#       "proceedsFromIssuanceOfCommonStock": "None",
#       "proceedsFromIssuanceOfLongTermDebtAndCapitalSecuritiesNet": "None",
#       "proceedsFromIssuanceOfPreferredStock": "None",
#       "proceedsFromRepurchaseOfEquity": "None",
#       "proceedsFromSaleOfTreasuryStock": "None",
#       "changeInCashAndCashEquivalents": "None",
#       "changeInExchangeRate": "None",
#       "netIncome": "1708000000"
#     },
#     {
#       "fiscalDateEnding": "2005-12-31",
#       "reportedCurrency": "USD",
#       "operatingCashflow": "5428000000",
#       "paymentsForOperatingActivities": "None",
#       "proceedsFromOperatingActivities": "None",
#       "changeInOperatingLiabilities": "None",
#       "changeInOperatingAssets": "None",
#       "depreciationDepletionAndAmortization": "1329000000",
#       "capitalExpenditures": "2179000000",
#       "changeInReceivables": "None",
#       "changeInInventory": "202000000",
#       "profitLoss": "None",
#       "cashflowFromInvestment": "None",
#       "cashflowFromFinancing": "496000000",
#       "proceedsFromRepaymentsOfShortTermDebt": "None",
#       "paymentsForRepurchaseOfCommonStock": "None",
#       "paymentsForRepurchaseOfEquity": "None",
#       "paymentsForRepurchaseOfPreferredStock": "None",
#       "dividendPayout": "316000000",
#       "dividendPayoutCommonStock": "316000000",
#       "dividendPayoutPreferredStock": "None",
#       "proceedsFromIssuanceOfCommonStock": "None",
#       "proceedsFromIssuanceOfLongTermDebtAndCapitalSecuritiesNet": "None",
#       "proceedsFromIssuanceOfPreferredStock": "None",
#       "proceedsFromRepurchaseOfEquity": "None",
#       "proceedsFromSaleOfTreasuryStock": "None",
#       "changeInCashAndCashEquivalents": "None",
#       "changeInExchangeRate": "None",
#       "netIncome": "3160000000"
#     },
#     {
#       "fiscalDateEnding": "2005-09-30",
#       "reportedCurrency": "USD",
#       "operatingCashflow": "4280000000",
#       "paymentsForOperatingActivities": "None",
#       "proceedsFromOperatingActivities": "None",
#       "changeInOperatingLiabilities": "None",
#       "changeInOperatingAssets": "None",
#       "depreciationDepletionAndAmortization": "1239000000",
#       "capitalExpenditures": "1030000000",
#       "changeInReceivables": "None",
#       "changeInInventory": "None",
#       "profitLoss": "None",
#       "cashflowFromInvestment": "None",
#       "cashflowFromFinancing": "-3712000000",
#       "proceedsFromRepaymentsOfShortTermDebt": "None",
#       "paymentsForRepurchaseOfCommonStock": "None",
#       "paymentsForRepurchaseOfEquity": "None",
#       "paymentsForRepurchaseOfPreferredStock": "None",
#       "dividendPayout": "319000000",
#       "dividendPayoutCommonStock": "319000000",
#       "dividendPayoutPreferredStock": "None",
#       "proceedsFromIssuanceOfCommonStock": "None",
#       "proceedsFromIssuanceOfLongTermDebtAndCapitalSecuritiesNet": "None",
#       "proceedsFromIssuanceOfPreferredStock": "None",
#       "proceedsFromRepurchaseOfEquity": "None",
#       "proceedsFromSaleOfTreasuryStock": "None",
#       "changeInCashAndCashEquivalents": "None",
#       "changeInExchangeRate": "None",
#       "netIncome": "1516000000"
#     },
#     {
#       "fiscalDateEnding": "2005-06-30",
#       "reportedCurrency": "USD",
#       "operatingCashflow": "3128000000",
#       "paymentsForOperatingActivities": "None",
#       "proceedsFromOperatingActivities": "None",
#       "changeInOperatingLiabilities": "None",
#       "changeInOperatingAssets": "None",
#       "depreciationDepletionAndAmortization": "1338000000",
#       "capitalExpenditures": "1070000000",
#       "changeInReceivables": "None",
#       "changeInInventory": "None",
#       "profitLoss": "None",
#       "cashflowFromInvestment": "None",
#       "cashflowFromFinancing": "-1344000000",
#       "proceedsFromRepaymentsOfShortTermDebt": "None",
#       "paymentsForRepurchaseOfCommonStock": "None",
#       "paymentsForRepurchaseOfEquity": "None",
#       "paymentsForRepurchaseOfPreferredStock": "None",
#       "dividendPayout": "321000000",
#       "dividendPayoutCommonStock": "321000000",
#       "dividendPayoutPreferredStock": "None",
#       "proceedsFromIssuanceOfCommonStock": "None",
#       "proceedsFromIssuanceOfLongTermDebtAndCapitalSecuritiesNet": "None",
#       "proceedsFromIssuanceOfPreferredStock": "None",
#       "proceedsFromRepurchaseOfEquity": "None",
#       "proceedsFromSaleOfTreasuryStock": "None",
#       "changeInCashAndCashEquivalents": "None",
#       "changeInExchangeRate": "None",
#       "netIncome": "1829000000"
#     },
#     {
#       "fiscalDateEnding": "2005-03-31",
#       "reportedCurrency": "USD",
#       "operatingCashflow": "2078000000",
#       "paymentsForOperatingActivities": "None",
#       "proceedsFromOperatingActivities": "None",
#       "changeInOperatingLiabilities": "None",
#       "changeInOperatingAssets": "None",
#       "depreciationDepletionAndAmortization": "1282000000",
#       "capitalExpenditures": "956000000",
#       "changeInReceivables": "None",
#       "changeInInventory": "None",
#       "profitLoss": "None",
#       "cashflowFromInvestment": "None",
#       "cashflowFromFinancing": "-2587000000",
#       "proceedsFromRepaymentsOfShortTermDebt": "None",
#       "paymentsForRepurchaseOfCommonStock": "None",
#       "paymentsForRepurchaseOfEquity": "None",
#       "paymentsForRepurchaseOfPreferredStock": "None",
#       "dividendPayout": "294000000",
#       "dividendPayoutCommonStock": "294000000",
#       "dividendPayoutPreferredStock": "None",
#       "proceedsFromIssuanceOfCommonStock": "None",
#       "proceedsFromIssuanceOfLongTermDebtAndCapitalSecuritiesNet": "None",
#       "proceedsFromIssuanceOfPreferredStock": "None",
#       "proceedsFromRepurchaseOfEquity": "None",
#       "proceedsFromSaleOfTreasuryStock": "None",
#       "changeInCashAndCashEquivalents": "None",
#       "changeInExchangeRate": "None",
#       "netIncome": "1402000000"
#     }
#   ]
# }
#
# --- get_news_sentiment ---
# Dict keys (1 total), sample: {
#   "Information": "We have detected your API key as JTPKOHNIT0NJYEQ2 and our standard API rate limit is 25 requests per day. Please subscribe to any of the premium plans at https://www.alphavantage.co/premium/ to instantly remove all daily rate limits."
# }
#
# --- calculate_key_metrics ---
# Dict keys (5 total), sample: {
#   "Price": 0.0,
#   "MarketCap": 0.0,
#   "PE_Ratio": 0.0,
#   "PB_Ratio": 0.0,
#   "DividendYield": 0.0
# }
#
# All tests complete.

# %% [markdown]
# ## Fetching Daily Stock Data
#
# Get daily adjusted price data for an Indian stock (using NSE/BSE extensions)

# %%
# Fetch daily adjusted data for Reliance Industries from NSE
reliance_daily = client.get_daily_adjusted("RELIANCE.NS")

# Display the last 5 data points
reliance_daily.tail()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Plot the closing price
plt.figure(figsize=(12, 6))
plt.plot(reliance_daily.index, reliance_daily['adjusted close'])
plt.title('Reliance Industries - Adjusted Close Price')
plt.xlabel('Date')
plt.ylabel('Price (INR)')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 3
#       1 # Plot the closing price
#       2 plt.figure(figsize=(12, 6))
# ----> 3 plt.plot(reliance_daily.index, reliance_daily['adjusted close'])
#       4 plt.title('Reliance Industries - Adjusted Close Price')
#       5 plt.xlabel('Date')
#
# File ~/hobby_projects/trader/investment_machine/venv/lib/python3.9/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~/hobby_projects/trader/investment_machine/venv/lib/python3.9/site-packages/pandas/core/indexes/range.py:417, in RangeIndex.get_loc(self, key)
#     415         raise KeyError(key) from err
#     416 if isinstance(key, Hashable):
# --> 417     raise KeyError(key)
#     418 self._check_indexing_error(key)
#     419 raise KeyError(key)
#
# KeyError: 'adjusted close'

# %% [markdown]
# ## Fetching Fundamental Data
#
# Retrieve company overview and financial statements

# %%
# Get company overview
overview = client.get_company_overview("RELIANCE.NS")

# Display selected information
selected_info = {
    key: overview.get(key) for key in [
        "Symbol", "Name", "Description", "Sector", "Industry", "MarketCapitalization",
        "PERatio", "PEGRatio", "BookValue", "DividendYield", "EPS", "ProfitMargin", "ROE"
    ]
}

pd.Series(selected_info)
# Out:
# Symbol                  None
# Name                    None
# Description             None
# Sector                  None
# Industry                None
# MarketCapitalization    None
# PERatio                 None
# PEGRatio                None
# BookValue               None
# DividendYield           None
# EPS                     None
# ProfitMargin            None
# ROE                     None
# dtype: object

# %%
# Get income statement
income_statement = client.get_income_statement("RELIANCE.NS")

# Extract annual reports and create a DataFrame
annual_reports = income_statement.get("annualReports", [])
if annual_reports:
    # Create a DataFrame with key metrics
    metrics = [
        "fiscalDateEnding", "totalRevenue", "grossProfit", "operatingIncome", 
        "netIncome", "ebitda"
    ]
    
    # Extract data for each year
    data = []
    for report in annual_reports:
        data.append({metric: report.get(metric) for metric in metrics})
        
    # Create and display DataFrame
    income_df = pd.DataFrame(data)
    income_df.set_index("fiscalDateEnding", inplace=True)
    
    # Convert to numeric
    income_df = income_df.apply(pd.to_numeric)
    
    # Display in millions
    (income_df / 1_000_000).round(2)

# %% [markdown]
# ## Calculate Key Financial Metrics
#
# Use the helper method to calculate key financial metrics

# %%
# Calculate key metrics for Reliance
metrics = client.calculate_key_metrics("RELIANCE.NS")

# Display metrics
pd.Series(metrics)

# %% [markdown]
# ## News & Sentiment Analysis
#
# Retrieve recent news and sentiment data

# %%
# Get news for Reliance, limit to 10 items
news = client.get_news_sentiment(symbol="RELIANCE.NS", limit=10)

# Process and display news items
news_items = news.get("feed", [])
if news_items:
    # Create a list of news with relevant information
    processed_news = []
    for item in news_items:
        processed_news.append({
            "title": item.get("title"),
            "time_published": item.get("time_published"),
            "sentiment": item.get("overall_sentiment_label"),
            "sentiment_score": item.get("overall_sentiment_score"),
            "url": item.get("url")
        })
    
    # Create and display DataFrame
    news_df = pd.DataFrame(processed_news)
    news_df

# %% [markdown]
# ## Topic-based News
#
# Retrieve news based on specific topics relevant to Indian markets

# %%
# Get news for specific topics (e.g., economy, ipo, technology)
topic_news = client.get_news_sentiment(topics="economy,ipo,technology", limit=10)

# Process and display topic-based news
topic_items = topic_news.get("feed", [])
if topic_items:
    # Create a list of news with relevant information
    processed_topics = []
    for item in topic_items:
        processed_topics.append({
            "title": item.get("title"),
            "time_published": item.get("time_published"),
            "topics": ", ".join([topic.get("topic") for topic in item.get("topics", [])]),
            "sentiment": item.get("overall_sentiment_label"),
            "url": item.get("url")
        })
    
    # Create and display DataFrame
    topics_df = pd.DataFrame(processed_topics)
    topics_df
